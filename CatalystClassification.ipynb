# %% [markdown]
# # Catalyst Steel Segmentation
#
#
#
# From: https://github.com/chizhu/kaggle-severstal
#
#
# Applies 5 class classification including background class and then 4 class segmentation.
#
# Classification: resnet50, efficientnet-b3 and se-resnext50.
#
# Segmentation: Unet with resnet18, PSPNet with resnet18 and FPN with resnet50.

# %% [markdown]
# ## Copy files from Google Drive

# %%
# mount the google drive
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
root_dir = "/content/gdrive/My Drive/"
base_dir = root_dir + 'Steel Segmentation/'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# ## Copy python utils

# %%
import os

# %%
# copy the specified folder from google drive
def copy_support_directory( name ):  
  if os.path.exists(name): 
    # !rm -r {name}    
  # !mkdir {name}
  gd_dir = base_dir + name
  # !cp -r '{gd_dir}/'* {name}/.

# %%
copy_support_directory( 'utils' )
copy_support_directory( 'schedulers' )
copy_support_directory( 'transforms' )
copy_support_directory( 'losses' )
copy_support_directory( 'datasets' )
copy_support_directory( 'optimizers' )

# %% [markdown]
# ## Copy python models

# %%
copy_support_directory( 'models' )

# %% [markdown]
# ## Copy config files

# %%
copy_support_directory( 'config' )

# %% [markdown]
# ## Copy the original image data

# %%
# %%time

# get the image zip files using gdown as drive mapping was timing out
import gdown

# the directory containing the original competition data
data_dir = 'SteelDefect'

# test if the images are already here
if os.path.isdir(data_dir):
  # !rm -r {data_dir}

# !gdown --id 1fE3ITnDMGWdyckgynmLhWEN4DzJKDxtw
# !mkdir -p {data_dir}
# !unzip -q severstal-steel-defect-detection.zip -d {data_dir}
# !rm severstal-steel-defect-detection.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1fE3ITnDMGWdyckgynmLhWEN4DzJKDxtw
# To: /content/severstal-steel-defect-detection.zip
# 1.68GB [00:22, 75.8MB/s]
# CPU times: user 226 ms, sys: 62.8 ms, total: 289 ms
# Wall time: 1min 33s

# %%
# !ls
# Out:
# config	  gdrive  models      sample_data  SteelDefect	utils
# datasets  losses  optimizers  schedulers   transforms

# %% [markdown]
# ## Get Required Libraries

# %%
# for augmentations
# !pip install albumentations -q

# for pretrained segmentation models fo PyTorch
# !pip install segmentation-models-pytorch -q

# for TTA
# !pip install ttach==0.0.2 -q

# for Catalyst
# !pip install -U catalyst -q
# Out:
#      |████████████████████████████████| 634kB 4.7MB/s
#   Building wheel for imgaug (setup.py) ... done
#      |████████████████████████████████| 51kB 2.5MB/s
#      |████████████████████████████████| 61kB 4.5MB/s
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Building wheel for pretrainedmodels (setup.py) ... done
#      |████████████████████████████████| 399kB 4.4MB/s
#      |████████████████████████████████| 317kB 12.9MB/s
#      |████████████████████████████████| 163kB 14.5MB/s
#      |████████████████████████████████| 71kB 7.7MB/s

# %%
import argparse

from pathlib import Path
from collections import defaultdict

import numpy as np
import pandas as pd
from numpy.random.mtrand import RandomState
from sklearn.model_selection import StratifiedKFold
from tqdm import tqdm_notebook as tqdm

import warnings
warnings.filterwarnings("ignore")

from catalyst.dl import SupervisedRunner
from catalyst.dl.callbacks import CheckpointCallback, F1ScoreCallback
from utils.metrics import MultiClassAccuracyCallback

from models import CustomNet

from utils.config import load_config, save_config
from datasets import make_loader
from optimizers import get_optimizer
from losses import get_loss
from schedulers import get_scheduler
from transforms import get_transforms

# %%
MASKS = Path(data_dir + '/train.csv')
IMAGES = Path(data_dir + '/train_images')

gd_original_train_csv = base_dir + 'Input/orig_train.csv'

def create_original_train_csv():
  """ copy or create the original training CSV file
      - this had a single column for 'ImageId_ClassId' as opposed to sepate columns
      - additionally had an entry for each defect on each image rather than only entries
        when a defect is present
  """

  # test if the masks.csv file already exists on google drive
  if os.path.exists(gd_original_train_csv): 

    # copy the original training csv file from google drive

    print(f"Copying {gd_original_train_csv}")
    # !cp '{gd_original_train_csv}' SteelDefect/.

  else:

    # need to create the masks dataframe from the training dataframe
    # - this takes about 5 minutes
    df_masks = pd.read_csv(MASKS)

    # add an 'ImageId_ClassId' column to put things back into the old format
    df_masks['ImageId_ClassId'] = df_masks.apply (lambda row: row.ImageId + '_' + str(row.ClassId) , axis=1)
    df_masks.drop(columns=['ImageId','ClassId'],inplace=True)

    # swap the column order to match the original
    columns_titles = ["ImageId_ClassId","EncodedPixels"]
    df_masks=df_masks.reindex(columns=columns_titles)

    # add blank entries for defects
    fnames = os.listdir(IMAGES)
    for fname in tqdm(fnames):
      for defect in range(1,5):
        defect_image = f"{fname}_{defect}"    
        if defect_image not in df_masks["ImageId_ClassId"].values:   
          row_df = pd.DataFrame([defect_image],columns=['ImageId_ClassId'])
          df_masks = pd.concat([row_df, df_masks], ignore_index=True)

    df_masks = df_masks.sort_values(["ImageId_ClassId"])  
    df_masks = df_masks.reset_index(drop=True) 

    # this file is 17MB in size and takes a long time to generate, so make sure its saved
    # - make sure it retains the indexes as these are the image names
    df_masks.to_csv(gd_original_train_csv, index=False)

    # save a version to the input directory for use now
    df_masks.to_csv('SteelDefect/orig_train.csv', index=False)

# %%
def stratified_group_k_fold(
        label: str,
        group_column: str,
        df: pd.DataFrame = None,
        file: str = None,
        n_splits=5,
        seed: int = 0
):
    random_state = RandomState(seed)

    if file is not None:
        df = pd.read_csv(file)

    labels = defaultdict(set)
    for g, l in zip(df[group_column], df[label]):
        labels[g].add(l)

    group_labels = dict()
    groups = []
    Y = []
    for k, v in labels.items():
        group_labels[k] = random_state.choice(list(v))
        Y.append(group_labels[k])
        groups.append(k)

    index = np.arange(len(group_labels))
    folds = StratifiedKFold(n_splits=n_splits, shuffle=True,
                            random_state=random_state).split(index, Y)

    group_folds = dict()
    for i, (train, val) in enumerate(folds):
        for j in val:
            group_folds[groups[j]] = i

    res = np.zeros(len(df))
    for i, g in enumerate(df[group_column]):
        res[i] = group_folds[g]

    return res.astype(np.int)


def stratified_k_fold(
        label: str, df: pd.DataFrame = None, file: str = None, n_splits=5,
        seed: int = 0
):
    random_state = RandomState(seed)

    if file is not None:
        df = pd.read_csv(file)

    index = np.arange(df.shape[0])
    res = np.zeros(index.shape)
    folds = StratifiedKFold(n_splits=n_splits,
                            random_state=random_state,
                            shuffle=True).split(index, df[label])

    for i, (train, val) in enumerate(folds):
        res[val] = i
    return res.astype(np.int)


def split_folds(config_file):
    config = load_config(config_file)
    os.makedirs(config.work_dir, exist_ok=True)

    # test if the folds.csv file already exists on google drive
    gd_folds_csv = base_dir + 'Input/folds.csv'
    if os.path.exists(gd_folds_csv): 
    
      # copy the folds csv file from google drive
      print(f"Copying {gd_folds_csv}")
      # !cp '{gd_folds_csv}' .

    else:    

      print(f"Creating folds.csv")

      df = pd.read_csv(config.data.train_df_path)
      df['ImageId'], df['ClassId'] = zip(*df['ImageId_ClassId'].str.split('_'))
      df['ClassId'] = df['ClassId'].astype(int)
      df['exists'] = df['EncodedPixels'].notnull().astype(int)
      df['ClassId0'] = [row.ClassId if row.exists else 0 for row in df.itertuples()]
      df['fold'] = stratified_group_k_fold(
          label='ClassId0', group_column='ImageId', df=df, n_splits=config.data.params.num_folds
      )
      pv_df = df.pivot(index='ImageId', columns='ClassId', values='EncodedPixels')
      pv_df = pv_df.merge(df[['ImageId', 'fold']], on='ImageId', how='left')
      pv_df = pv_df.drop_duplicates()
      pv_df = pv_df.set_index('ImageId')
      pv_df.to_csv('folds.csv')

      # save a copy back on google drive     
      pv_df.to_csv(gd_folds_csv)


def create_folds(config_file):
    print('split train dataset for Severstal Steel Defect Detection.')    
    if config_file is None:
        raise Exception('no configuration file')
    print('load config from {}'.format(config_file))

    # make sure we have the original training csv
    create_original_train_csv()

    # split the data into folds
    split_folds(config_file)

# %%
create_folds('config/base_config.yml')
# Out:
# split train dataset for Severstal Steel Defect Detection.
# load config from config/base_config.yml
# Copying /content/gdrive/My Drive/Steel Segmentation/Input/orig_train.csv
# Copying /content/gdrive/My Drive/Steel Segmentation/Input/folds.csv

# %% [markdown]
# # Classification

# %%
model_dir = base_dir + 'Output/Model/'

def run(config_file):
    config = load_config(config_file)

    os.makedirs(config.work_dir, exist_ok=True)
    save_config(config, config.work_dir + '/config.yml')

    os.environ['CUDA_VISIBLE_DEVICES'] = '0'

    all_transforms = {}
    all_transforms['train'] = get_transforms(config.transforms.train)
    all_transforms['valid'] = get_transforms(config.transforms.test)

    dataloaders = {
        phase: make_loader(
            data_folder=config.data.train_dir,
            df_path=config.data.train_df_path,
            phase=phase,
            batch_size=config.train.batch_size,
            num_workers=config.num_workers,
            idx_fold=config.data.params.idx_fold,
            transforms=all_transforms[phase],
            num_classes=config.data.num_classes,
            pseudo_label_path=config.train.pseudo_label_path,
            task='cls'
        )
        for phase in ['train', 'valid']
    }

    # create model
    model = CustomNet(config.model.encoder, config.data.num_classes)

    # train setting
    criterion = get_loss(config)
    params = [
        {'params': model.base_params(), 'lr': config.optimizer.params.encoder_lr},
        {'params': model.fresh_params(), 'lr': config.optimizer.params.decoder_lr}
    ]
    optimizer = get_optimizer(params, config)
    scheduler = get_scheduler(optimizer, config)

    # model runner
    runner = SupervisedRunner(model=model)

    callbacks = [MultiClassAccuracyCallback(threshold=0.5), F1ScoreCallback()]

    if os.path.exists(config.work_dir + '/checkpoints/best.pth'):
        callbacks.append(CheckpointCallback(resume=config.work_dir + '/checkpoints/best_full.pth'))

    # model training
    runner.train(
        model=model,
        criterion=criterion,
        optimizer=optimizer,
        scheduler=scheduler,
        loaders=dataloaders,
        logdir=config.work_dir,
        num_epochs=config.train.num_epochs,
        callbacks=callbacks,
        verbose=True,
        fp16=True,
    )


def parse_args():
    parser = argparse.ArgumentParser(description='Severstal')
    parser.add_argument('--config', dest='config_file',
                        help='configuration filename',
                        default=None, type=str)
    return parser.parse_args()


def main(config_file):
    print('train Severstal Steel Defect Detection.')    
    if config_file is None:
        raise Exception('no configuration file')
    print('load config from {}'.format(config_file))
    run(config_file)

# %%
# !ls config/cls
# Out:
# 001_resnet50_BCE_5class_fold0.yml      003_seresnext50_cls_BCE_5class_fold2.yml
# 002_efnet_b3_cls_BCE_5class_fold1.yml

# %%
# main('config/cls/001_resnet50_BCE_5class_fold0.yml')
# !cp -r 001_resnet50_BCE_5class_fold0 '/content/gdrive/My Drive/Steel Segmentation/'

# %%
# main('config/cls/002_efnet_b3_cls_BCE_5class_fold1.yml')
# !cp -r 002_efnet_b3_cls_BCE_5class_fold1 '/content/gdrive/My Drive/Steel Segmentation/'

# %%
main('config/cls/003_seresnext50_cls_BCE_5class_fold2.yml')
# !cp -r 003_seresnext50_cls_BCE_5class_fold2 '/content/gdrive/My Drive/Steel Segmentation/'
# Out:
# train Severstal Steel Defect Detection.
# load config from config/cls/003_seresnext50_cls_BCE_5class_fold2.yml
# Downloading: "http://data.lip6.fr/cadene/pretrainedmodels/se_resnext50_32x4d-a260b3a4.pth" to /root/.cache/torch/checkpoints/se_resnext50_32x4d-a260b3a4.pth
# HBox(children=(FloatProgress(value=0.0, max=110559176.0), HTML(value='')))
# 1/40 * Epoch (train): 100% 1257/1257 [17:22<00:00,  1.21it/s, accuracy=0.967, f1_score=0.865, loss=0.061]
# 1/40 * Epoch (valid): 100% 315/315 [00:53<00:00,  5.87it/s, accuracy=1.000, f1_score=0.998, loss=8.200e-04]
# [2020-07-14 08:25:19,527]
# 1/40 * Epoch 1 (_base): lr=0.0001 | momentum=0.9000
# 1/40 * Epoch 1 (train): accuracy=0.9324 | f1_score=0.7609 | loss=0.1640
# 1/40 * Epoch 1 (valid): accuracy=0.9667 | f1_score=0.8841 | loss=0.0907
# 2/40 * Epoch (train): 100% 1257/1257 [17:23<00:00,  1.20it/s, accuracy=0.900, f1_score=0.691, loss=0.373]
# 2/40 * Epoch (valid): 100% 315/315 [00:53<00:00,  5.86it/s, accuracy=1.000, f1_score=0.999, loss=4.725e-04]
# [2020-07-14 08:43:40,012]
# 2/40 * Epoch 2 (_base): lr=0.0001 | momentum=0.9000
# 2/40 * Epoch 2 (train): accuracy=0.9639 | f1_score=0.8733 | loss=0.0932
# 2/40 * Epoch 2 (valid): accuracy=0.9682 | f1_score=0.8918 | loss=0.0850
# 3/40 * Epoch (train): 100% 1257/1257 [17:22<00:00,  1.21it/s, accuracy=1.000, f1_score=0.886, loss=0.053]
# 3/40 * Epoch (valid): 100% 315/315 [00:53<00:00,  5.83it/s, accuracy=1.000, f1_score=1.000, loss=2.850e-05]
# [2020-07-14 09:02:01,452]
# 3/40 * Epoch 3 (_base): lr=0.0001 | momentum=0.9000
# 3/40 * Epoch 3 (train): accuracy=0.9707 | f1_score=0.8956 | loss=0.0773
# 3/40 * Epoch 3 (valid): accuracy=0.9729 | f1_score=0.9084 | loss=0.0689
# 4/40 * Epoch (train): 100% 1257/1257 [17:22<00:00,  1.21it/s, accuracy=1.000, f1_score=0.972, loss=0.012]
# 4/40 * Epoch (valid): 100% 315/315 [00:53<00:00,  5.85it/s, accuracy=1.000, f1_score=0.999, loss=2.388e-04]
# [2020-07-14 09:20:21,178]
# 4/40 * Epoch 4 (_base): lr=0.0001 | momentum=0.9000
# 4/40 * Epoch 4 (train): accuracy=0.9756 | f1_score=0.9123 | loss=0.0655
# 4/40 * Epoch 4 (valid): accuracy=0.9757 | f1_score=0.9250 | loss=0.0699
# 5/40 * Epoch (train): 100% 1257/1257 [17:22<00:00,  1.21it/s, accuracy=0.767, f1_score=0.504, loss=0.488]
# 5/40 * Epoch (valid): 100% 315/315 [00:53<00:00,  5.85it/s, accuracy=1.000, f1_score=1.000, loss=4.919e-05]
# [2020-07-14 09:38:39,620]
# 5/40 * Epoch 5 (_base): lr=0.0001 | momentum=0.9000
# 5/40 * Epoch 5 (train): accuracy=0.9778 | f1_score=0.9213 | loss=0.0599
# 5/40 * Epoch 5 (valid): accuracy=0.9765 | f1_score=0.9254 | loss=0.0689
# 6/40 * Epoch (train): 100% 1257/1257 [17:22<00:00,  1.21it/s, accuracy=1.000, f1_score=0.999, loss=2.815e-04]
# 6/40 * Epoch (valid): 100% 315/315 [00:53<00:00,  5.88it/s, accuracy=1.000, f1_score=1.000, loss=1.184e-05]
# [2020-07-14 09:56:59,560]
# 6/40 * Epoch 6 (_base): lr=0.0001 | momentum=0.9000
# 6/40 * Epoch 6 (train): accuracy=0.9805 | f1_score=0.9300 | loss=0.0525
# 6/40 * Epoch 6 (valid): accuracy=0.9772 | f1_score=0.9243 | loss=0.0667
# 7/40 * Epoch (train): 100% 1257/1257 [17:23<00:00,  1.21it/s, accuracy=1.000, f1_score=0.977, loss=0.011]
# 7/40 * Epoch (valid): 100% 315/315 [00:53<00:00,  5.86it/s, accuracy=1.000, f1_score=1.000, loss=8.285e-06]
# [2020-07-14 10:15:19,847]
# 7/40 * Epoch 7 (_base): lr=0.0001 | momentum=0.9000
# 7/40 * Epoch 7 (train): accuracy=0.9828 | f1_score=0.9382 | loss=0.0476
# 7/40 * Epoch 7 (valid): accuracy=0.9801 | f1_score=0.9329 | loss=0.0563
# 8/40 * Epoch (train): 100% 1257/1257 [17:23<00:00,  1.20it/s, accuracy=1.000, f1_score=0.991, loss=0.004]
# 8/40 * Epoch (valid): 100% 315/315 [00:53<00:00,  5.87it/s, accuracy=1.000, f1_score=1.000, loss=1.729e-06]
# [2020-07-14 10:33:40,079]
# 8/40 * Epoch 8 (_base): lr=0.0001 | momentum=0.9000
# 8/40 * Epoch 8 (train): accuracy=0.9845 | f1_score=0.9445 | loss=0.0423
# 8/40 * Epoch 8 (valid): accuracy=0.9722 | f1_score=0.9231 | loss=0.0832
# 9/40 * Epoch (train): 100% 1257/1257 [17:23<00:00,  1.20it/s, accuracy=1.000, f1_score=0.996, loss=0.002]
# 9/40 * Epoch (valid): 100% 315/315 [00:53<00:00,  5.88it/s, accuracy=1.000, f1_score=1.000, loss=1.054e-05]
# [2020-07-14 10:51:58,761]
# 9/40 * Epoch 9 (_base): lr=0.0001 | momentum=0.9000
# 9/40 * Epoch 9 (train): accuracy=0.9859 | f1_score=0.9494 | loss=0.0395
# 9/40 * Epoch 9 (valid): accuracy=0.9789 | f1_score=0.9319 | loss=0.0691
# 10/40 * Epoch (train): 100% 1257/1257 [17:23<00:00,  1.21it/s, accuracy=1.000, f1_score=0.967, loss=0.017]
# 10/40 * Epoch (valid): 100% 315/315 [00:53<00:00,  5.84it/s, accuracy=1.000, f1_score=1.000, loss=1.883e-06]
# [2020-07-14 11:10:17,595]
# 10/40 * Epoch 10 (_base): lr=5.000e-05 | momentum=0.9000
# 10/40 * Epoch 10 (train): accuracy=0.9863 | f1_score=0.9532 | loss=0.0361
# 10/40 * Epoch 10 (valid): accuracy=0.9788 | f1_score=0.9347 | loss=0.0627
# 11/40 * Epoch (train): 100% 1257/1257 [17:23<00:00,  1.20it/s, accuracy=1.000, f1_score=0.997, loss=0.001]
# 11/40 * Epoch (valid): 100% 315/315 [00:53<00:00,  5.86it/s, accuracy=1.000, f1_score=1.000, loss=1.621e-06]
# [2020-07-14 11:28:37,108]
# 11/40 * Epoch 11 (_base): lr=5.000e-05 | momentum=0.9000
# 11/40 * Epoch 11 (train): accuracy=0.9921 | f1_score=0.9714 | loss=0.0208
# 11/40 * Epoch 11 (valid): accuracy=0.9827 | f1_score=0.9509 | loss=0.0563
# 12/40 * Epoch (train): 100% 1257/1257 [17:23<00:00,  1.20it/s, accuracy=1.000, f1_score=0.993, loss=0.003]
# 12/40 * Epoch (valid): 100% 315/315 [00:53<00:00,  5.86it/s, accuracy=1.000, f1_score=1.000, loss=7.272e-07]
# [2020-07-14 11:46:56,145]
# 12/40 * Epoch 12 (_base): lr=5.000e-05 | momentum=0.9000
# 12/40 * Epoch 12 (train): accuracy=0.9935 | f1_score=0.9754 | loss=0.0181
# 12/40 * Epoch 12 (valid): accuracy=0.9811 | f1_score=0.9512 | loss=0.0659
# 13/40 * Epoch (train): 100% 1257/1257 [17:23<00:00,  1.20it/s, accuracy=1.000, f1_score=0.986, loss=0.006]
# 13/40 * Epoch (valid): 100% 315/315 [00:53<00:00,  5.87it/s, accuracy=1.000, f1_score=1.000, loss=2.861e-07]
# [2020-07-14 12:05:15,414]
# 13/40 * Epoch 13 (_base): lr=2.500e-05 | momentum=0.9000
# 13/40 * Epoch 13 (train): accuracy=0.9947 | f1_score=0.9811 | loss=0.0143
# 13/40 * Epoch 13 (valid): accuracy=0.9805 | f1_score=0.9438 | loss=0.0735
# 14/40 * Epoch (train): 100% 1257/1257 [17:23<00:00,  1.20it/s, accuracy=1.000, f1_score=0.985, loss=0.006]
# 14/40 * Epoch (valid): 100% 315/315 [00:53<00:00,  5.86it/s, accuracy=1.000, f1_score=1.000, loss=2.289e-06]
# [2020-07-14 12:23:34,212]
# 14/40 * Epoch 14 (_base): lr=2.500e-05 | momentum=0.9000
# 14/40 * Epoch 14 (train): accuracy=0.9960 | f1_score=0.9851 | loss=0.0108
# 14/40 * Epoch 14 (valid): accuracy=0.9842 | f1_score=0.9567 | loss=0.0629
# 15/40 * Epoch (train): 100% 1257/1257 [17:23<00:00,  1.20it/s, accuracy=1.000, f1_score=0.998, loss=7.775e-04]
# 15/40 * Epoch (valid): 100% 315/315 [00:54<00:00,  5.80it/s, accuracy=1.000, f1_score=1.000, loss=1.591e-05]
# [2020-07-14 12:41:54,215]
# 15/40 * Epoch 15 (_base): lr=2.500e-05 | momentum=0.9000
# 15/40 * Epoch 15 (train): accuracy=0.9974 | f1_score=0.9899 | loss=0.0070
# 15/40 * Epoch 15 (valid): accuracy=0.9837 | f1_score=0.9562 | loss=0.0658
# 16/40 * Epoch (train): 100% 1257/1257 [17:23<00:00,  1.20it/s, accuracy=1.000, f1_score=1.000, loss=5.719e-05]
# 16/40 * Epoch (valid): 100% 315/315 [00:53<00:00,  5.85it/s, accuracy=1.000, f1_score=1.000, loss=9.441e-06]
# [2020-07-14 13:00:13,571]
# 16/40 * Epoch 16 (_base): lr=1.250e-05 | momentum=0.9000
# 16/40 * Epoch 16 (train): accuracy=0.9980 | f1_score=0.9917 | loss=0.0058
# 16/40 * Epoch 16 (valid): accuracy=0.9832 | f1_score=0.9579 | loss=0.0736
# 17/40 * Epoch (train): 100% 1257/1257 [17:23<00:00,  1.20it/s, accuracy=1.000, f1_score=1.000, loss=1.058e-04]
# 17/40 * Epoch (valid): 100% 315/315 [00:53<00:00,  5.85it/s, accuracy=1.000, f1_score=1.000, loss=6.676e-07]
# [2020-07-14 13:18:32,831]
# 17/40 * Epoch 17 (_base): lr=1.250e-05 | momentum=0.9000
# 17/40 * Epoch 17 (train): accuracy=0.9985 | f1_score=0.9937 | loss=0.0046
# 17/40 * Epoch 17 (valid): accuracy=0.9839 | f1_score=0.9594 | loss=0.0793
# 18/40 * Epoch (train): 100% 1257/1257 [17:23<00:00,  1.20it/s, accuracy=1.000, f1_score=0.998, loss=0.001]
# 18/40 * Epoch (valid): 100% 315/315 [00:53<00:00,  5.85it/s, accuracy=1.000, f1_score=1.000, loss=2.384e-07]
# [2020-07-14 13:36:51,909]
# 18/40 * Epoch 18 (_base): lr=1.250e-05 | momentum=0.9000
# 18/40 * Epoch 18 (train): accuracy=0.9985 | f1_score=0.9945 | loss=0.0038
# 18/40 * Epoch 18 (valid): accuracy=0.9827 | f1_score=0.9565 | loss=0.0817
# 19/40 * Epoch (train): 100% 1257/1257 [17:23<00:00,  1.20it/s, accuracy=1.000, f1_score=0.999, loss=5.810e-04]
# 19/40 * Epoch (valid): 100% 315/315 [00:53<00:00,  5.84it/s, accuracy=1.000, f1_score=1.000, loss=1.431e-07]
# [2020-07-14 13:55:13,043]
# 19/40 * Epoch 19 (_base): lr=6.250e-06 | momentum=0.9000
# 19/40 * Epoch 19 (train): accuracy=0.9990 | f1_score=0.9955 | loss=0.0030
# 19/40 * Epoch 19 (valid): accuracy=0.9835 | f1_score=0.9583 | loss=0.0833
# 20/40 * Epoch (train): 100% 1257/1257 [17:23<00:00,  1.20it/s, accuracy=1.000, f1_score=1.000, loss=1.228e-06]
# 20/40 * Epoch (valid): 100% 315/315 [00:53<00:00,  5.84it/s, accuracy=1.000, f1_score=1.000, loss=1.073e-07]
# [2020-07-14 14:13:32,664]
# 20/40 * Epoch 20 (_base): lr=6.250e-06 | momentum=0.9000
# 20/40 * Epoch 20 (train): accuracy=0.9990 | f1_score=0.9962 | loss=0.0026
# 20/40 * Epoch 20 (valid): accuracy=0.9839 | f1_score=0.9587 | loss=0.0875
# 21/40 * Epoch (train): 100% 1257/1257 [17:23<00:00,  1.21it/s, accuracy=1.000, f1_score=1.000, loss=1.321e-04]
# 21/40 * Epoch (valid): 100% 315/315 [00:53<00:00,  5.84it/s, accuracy=1.000, f1_score=1.000, loss=5.960e-08]
# [2020-07-14 14:31:51,665]
# 21/40 * Epoch 21 (_base): lr=6.250e-06 | momentum=0.9000
# 21/40 * Epoch 21 (train): accuracy=0.9994 | f1_score=0.9972 | loss=0.0019
# 21/40 * Epoch 21 (valid): accuracy=0.9842 | f1_score=0.9599 | loss=0.0944
# 22/40 * Epoch (train): 100% 1257/1257 [17:23<00:00,  1.20it/s, accuracy=1.000, f1_score=1.000, loss=1.751e-05]
# 22/40 * Epoch (valid): 100% 315/315 [00:53<00:00,  5.83it/s, accuracy=1.000, f1_score=1.000, loss=7.272e-07]
# [2020-07-14 14:50:10,849]
# 22/40 * Epoch 22 (_base): lr=3.125e-06 | momentum=0.9000
# 22/40 * Epoch 22 (train): accuracy=0.9991 | f1_score=0.9965 | loss=0.0022
# 22/40 * Epoch 22 (valid): accuracy=0.9831 | f1_score=0.9579 | loss=0.0916
# 23/40 * Epoch (train): 100% 1257/1257 [17:24<00:00,  1.20it/s, accuracy=1.000, f1_score=1.000, loss=1.311e-07]
# 23/40 * Epoch (valid): 100% 315/315 [00:53<00:00,  5.85it/s, accuracy=1.000, f1_score=1.000, loss=1.883e-06]
# [2020-07-14 15:08:31,351]
# 23/40 * Epoch 23 (_base): lr=3.125e-06 | momentum=0.9000
# 23/40 * Epoch 23 (train): accuracy=0.9993 | f1_score=0.9974 | loss=0.0018
# 23/40 * Epoch 23 (valid): accuracy=0.9838 | f1_score=0.9596 | loss=0.0928
# 24/40 * Epoch (train): 100% 1257/1257 [17:23<00:00,  1.20it/s, accuracy=1.000, f1_score=1.000, loss=8.690e-05]
# 24/40 * Epoch (valid): 100% 315/315 [00:53<00:00,  5.85it/s, accuracy=1.000, f1_score=1.000, loss=5.257e-06]
# [2020-07-14 15:26:50,888]
# 24/40 * Epoch 24 (_base): lr=3.125e-06 | momentum=0.9000
# 24/40 * Epoch 24 (train): accuracy=0.9995 | f1_score=0.9979 | loss=0.0012
# 24/40 * Epoch 24 (valid): accuracy=0.9842 | f1_score=0.9608 | loss=0.0930
# 25/40 * Epoch (train): 100% 1257/1257 [17:23<00:00,  1.20it/s, accuracy=1.000, f1_score=1.000, loss=2.305e-07]
# 25/40 * Epoch (valid): 100% 315/315 [00:53<00:00,  5.84it/s, accuracy=1.000, f1_score=1.000, loss=6.556e-07]
# [2020-07-14 15:45:10,649]
# 25/40 * Epoch 25 (_base): lr=1.563e-06 | momentum=0.9000
# 25/40 * Epoch 25 (train): accuracy=0.9997 | f1_score=0.9981 | loss=0.0012
# 25/40 * Epoch 25 (valid): accuracy=0.9838 | f1_score=0.9609 | loss=0.0974
# 26/40 * Epoch (train): 100% 1257/1257 [17:23<00:00,  1.20it/s, accuracy=1.000, f1_score=1.000, loss=1.496e-04]
# 26/40 * Epoch (valid): 100% 315/315 [00:53<00:00,  5.84it/s, accuracy=1.000, f1_score=1.000, loss=2.623e-07]
# [2020-07-14 16:03:30,242]
# 26/40 * Epoch 26 (_base): lr=1.563e-06 | momentum=0.9000
# 26/40 * Epoch 26 (train): accuracy=0.9996 | f1_score=0.9982 | loss=0.0010
# 26/40 * Epoch 26 (valid): accuracy=0.9842 | f1_score=0.9602 | loss=0.0946
# 27/40 * Epoch (train): 100% 1257/1257 [17:23<00:00,  1.20it/s, accuracy=0.967, f1_score=0.965, loss=0.021]
# 27/40 * Epoch (valid): 100% 315/315 [00:53<00:00,  5.84it/s, accuracy=1.000, f1_score=1.000, loss=3.576e-08]
# [2020-07-14 16:21:49,460]
# 27/40 * Epoch 27 (_base): lr=1.563e-06 | momentum=0.9000
# 27/40 * Epoch 27 (train): accuracy=0.9995 | f1_score=0.9982 | loss=0.0011
# 27/40 * Epoch 27 (valid): accuracy=0.9844 | f1_score=0.9615 | loss=0.0972
# 28/40 * Epoch (train): 100% 1257/1257 [17:23<00:00,  1.20it/s, accuracy=1.000, f1_score=0.999, loss=2.382e-04]
# 28/40 * Epoch (valid): 100% 315/315 [00:53<00:00,  5.87it/s, accuracy=1.000, f1_score=1.000, loss=2.146e-07]
# [2020-07-14 16:40:09,001]
# 28/40 * Epoch 28 (_base): lr=7.813e-07 | momentum=0.9000
# 28/40 * Epoch 28 (train): accuracy=0.9996 | f1_score=0.9983 | loss=0.0012
# 28/40 * Epoch 28 (valid): accuracy=0.9845 | f1_score=0.9612 | loss=0.0983
# 29/40 * Epoch (train): 100% 1257/1257 [17:23<00:00,  1.20it/s, accuracy=1.000, f1_score=0.998, loss=8.642e-04]
# 29/40 * Epoch (valid): 100% 315/315 [00:54<00:00,  5.83it/s, accuracy=1.000, f1_score=1.000, loss=1.717e-06]
# [2020-07-14 16:58:28,906]
# 29/40 * Epoch 29 (_base): lr=7.813e-07 | momentum=0.9000
# 29/40 * Epoch 29 (train): accuracy=0.9997 | f1_score=0.9984 | loss=0.0011
# 29/40 * Epoch 29 (valid): accuracy=0.9838 | f1_score=0.9604 | loss=0.1021
# 30/40 * Epoch (train): 100% 1257/1257 [17:24<00:00,  1.20it/s, accuracy=1.000, f1_score=1.000, loss=9.237e-05]
# 30/40 * Epoch (valid): 100% 315/315 [00:53<00:00,  5.85it/s, accuracy=1.000, f1_score=1.000, loss=8.106e-07]
# [2020-07-14 17:16:49,059]
# 30/40 * Epoch 30 (_base): lr=7.813e-07 | momentum=0.9000
# 30/40 * Epoch 30 (train): accuracy=0.9997 | f1_score=0.9986 | loss=0.0008
# 30/40 * Epoch 30 (valid): accuracy=0.9846 | f1_score=0.9612 | loss=0.0942
# 31/40 * Epoch (train): 100% 1257/1257 [17:23<00:00,  1.20it/s, accuracy=1.000, f1_score=1.000, loss=1.971e-06]
# 31/40 * Epoch (valid): 100% 315/315 [00:54<00:00,  5.83it/s, accuracy=1.000, f1_score=1.000, loss=1.550e-07]
# [2020-07-14 17:35:08,317]
# 31/40 * Epoch 31 (_base): lr=3.906e-07 | momentum=0.9000
# 31/40 * Epoch 31 (train): accuracy=0.9997 | f1_score=0.9986 | loss=0.0008
# 31/40 * Epoch 31 (valid): accuracy=0.9841 | f1_score=0.9610 | loss=0.0971
# 32/40 * Epoch (train): 100% 1257/1257 [17:24<00:00,  1.20it/s, accuracy=1.000, f1_score=1.000, loss=3.103e-06]
# 32/40 * Epoch (valid): 100% 315/315 [00:54<00:00,  5.82it/s, accuracy=1.000, f1_score=1.000, loss=1.705e-06]
# [2020-07-14 17:53:28,671]
# 32/40 * Epoch 32 (_base): lr=3.906e-07 | momentum=0.9000
# 32/40 * Epoch 32 (train): accuracy=0.9997 | f1_score=0.9986 | loss=0.0009
# 32/40 * Epoch 32 (valid): accuracy=0.9842 | f1_score=0.9609 | loss=0.0995
# 33/40 * Epoch (train): 100% 1257/1257 [17:24<00:00,  1.20it/s, accuracy=1.000, f1_score=0.999, loss=4.724e-04]
# 33/40 * Epoch (valid): 100% 315/315 [00:53<00:00,  5.84it/s, accuracy=1.000, f1_score=1.000, loss=5.722e-07]
# [2020-07-14 18:11:48,617]
# 33/40 * Epoch 33 (_base): lr=3.906e-07 | momentum=0.9000
# 33/40 * Epoch 33 (train): accuracy=0.9996 | f1_score=0.9983 | loss=0.0010
# 33/40 * Epoch 33 (valid): accuracy=0.9846 | f1_score=0.9616 | loss=0.0982
# 34/40 * Epoch (train): 100% 1257/1257 [17:24<00:00,  1.20it/s, accuracy=1.000, f1_score=0.999, loss=5.578e-04]
# 34/40 * Epoch (valid): 100% 315/315 [00:53<00:00,  5.85it/s, accuracy=1.000, f1_score=1.000, loss=1.144e-06]
# [2020-07-14 18:30:08,659]
# 34/40 * Epoch 34 (_base): lr=1.953e-07 | momentum=0.9000
# 34/40 * Epoch 34 (train): accuracy=0.9997 | f1_score=0.9984 | loss=0.0011
# 34/40 * Epoch 34 (valid): accuracy=0.9844 | f1_score=0.9615 | loss=0.0994
# 35/40 * Epoch (train): 100% 1257/1257 [17:23<00:00,  1.20it/s, accuracy=1.000, f1_score=1.000, loss=2.475e-06]
# 35/40 * Epoch (valid): 100% 315/315 [00:53<00:00,  5.83it/s, accuracy=1.000, f1_score=1.000, loss=2.623e-07]
# [2020-07-14 18:48:28,332]
# 35/40 * Epoch 35 (_base): lr=1.953e-07 | momentum=0.9000
# 35/40 * Epoch 35 (train): accuracy=0.9995 | f1_score=0.9982 | loss=0.0015
# 35/40 * Epoch 35 (valid): accuracy=0.9846 | f1_score=0.9613 | loss=0.0986
# 36/40 * Epoch (train): 100% 1257/1257 [17:23<00:00,  1.20it/s, accuracy=1.000, f1_score=1.000, loss=1.026e-05]
# 36/40 * Epoch (valid): 100% 315/315 [00:53<00:00,  5.87it/s, accuracy=1.000, f1_score=1.000, loss=1.669e-07]
# [2020-07-14 19:06:47,871]
# 36/40 * Epoch 36 (_base): lr=1.953e-07 | momentum=0.9000
# 36/40 * Epoch 36 (train): accuracy=0.9996 | f1_score=0.9985 | loss=0.0009
# 36/40 * Epoch 36 (valid): accuracy=0.9846 | f1_score=0.9614 | loss=0.0966
# 37/40 * Epoch (train): 100% 1257/1257 [17:23<00:00,  1.20it/s, accuracy=1.000, f1_score=0.994, loss=0.003]
# 37/40 * Epoch (valid): 100% 315/315 [00:53<00:00,  5.86it/s, accuracy=1.000, f1_score=1.000, loss=1.378e-05]
# [2020-07-14 19:25:07,486]
# 37/40 * Epoch 37 (_base): lr=9.766e-08 | momentum=0.9000
# 37/40 * Epoch 37 (train): accuracy=0.9997 | f1_score=0.9988 | loss=0.0006
# 37/40 * Epoch 37 (valid): accuracy=0.9835 | f1_score=0.9605 | loss=0.1014
# 38/40 * Epoch (train): 100% 1257/1257 [17:23<00:00,  1.20it/s, accuracy=1.000, f1_score=1.000, loss=4.428e-05]
# 38/40 * Epoch (valid): 100% 315/315 [00:53<00:00,  5.85it/s, accuracy=1.000, f1_score=1.000, loss=3.934e-07]
# [2020-07-14 19:43:26,431]
# 38/40 * Epoch 38 (_base): lr=9.766e-08 | momentum=0.9000
# 38/40 * Epoch 38 (train): accuracy=0.9996 | f1_score=0.9985 | loss=0.0009
# 38/40 * Epoch 38 (valid): accuracy=0.9836 | f1_score=0.9611 | loss=0.0997
# 39/40 * Epoch (train): 100% 1257/1257 [17:23<00:00,  1.20it/s, accuracy=1.000, f1_score=1.000, loss=1.391e-07]
# 39/40 * Epoch (valid): 100% 315/315 [00:53<00:00,  5.85it/s, accuracy=1.000, f1_score=1.000, loss=8.345e-07]
# [2020-07-14 20:01:45,957]
# 39/40 * Epoch 39 (_base): lr=9.766e-08 | momentum=0.9000
# 39/40 * Epoch 39 (train): accuracy=0.9997 | f1_score=0.9986 | loss=0.0008
# 39/40 * Epoch 39 (valid): accuracy=0.9842 | f1_score=0.9609 | loss=0.0989
# 40/40 * Epoch (train): 100% 1257/1257 [17:23<00:00,  1.20it/s, accuracy=1.000, f1_score=1.000, loss=3.604e-06]
# 40/40 * Epoch (valid): 100% 315/315 [00:53<00:00,  5.86it/s, accuracy=1.000, f1_score=1.000, loss=7.153e-08]
# [2020-07-14 20:20:05,376]
# 40/40 * Epoch 40 (_base): lr=4.883e-08 | momentum=0.9000
# 40/40 * Epoch 40 (train): accuracy=0.9997 | f1_score=0.9987 | loss=0.0008
# 40/40 * Epoch 40 (valid): accuracy=0.9846 | f1_score=0.9614 | loss=0.0986
# Top best models:
# 003_seresnext50_cls_BCE_5class_fold2/checkpoints/train.7.pth	0.0563

# %%
# !ls
